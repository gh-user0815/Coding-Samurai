# %%
# Example for loading MNIST dataset using TensorFlow
import tensorflow as tf
from tensorflow.keras.datasets import mnist

(x_train, y_train), (x_test, y_test) = mnist.load_data()

# %%
type(x_train)
# Out:
# numpy.ndarray

# %%
# Example preprocessing using TensorFlow
print(x_train.shape, x_train[0].shape)
x_train = x_train.reshape((x_train.shape[0], 28, 28, 1)).astype('float32') / 255
x_test = x_test.reshape((x_test.shape[0], 28, 28, 1)).astype('float32') / 255
print(x_train.shape, x_train[0].shape)
# Out:
# (60000, 28, 28) (28, 28)
# (60000, 28, 28, 1) (28, 28, 1)

# %%
# Neural network using TensorFlow/Keras
model = tf.keras.Sequential([
    tf.keras.layers.Flatten(input_shape=(28, 28, 1)),
    tf.keras.layers.Dense(128, activation='relu'),
    tf.keras.layers.Dense(192, activation='relu'),
    tf.keras.layers.Dense(10, activation='softmax')
])

model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# %%
# Training using TensorFlow/Keras
model.fit(x_train, y_train, epochs=20, validation_data=(x_test, y_test))
# Out:
# Epoch 1/20
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.2278 - accuracy: 0.9320 - val_loss: 0.1161 - val_accuracy: 0.9627
# Epoch 2/20
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.0947 - accuracy: 0.9712 - val_loss: 0.0957 - val_accuracy: 0.9704
# Epoch 3/20
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0667 - accuracy: 0.9784 - val_loss: 0.0961 - val_accuracy: 0.9700
# Epoch 4/20
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0505 - accuracy: 0.9839 - val_loss: 0.0792 - val_accuracy: 0.9772
# Epoch 5/20
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0384 - accuracy: 0.9876 - val_loss: 0.0914 - val_accuracy: 0.9743
# Epoch 6/20
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0322 - accuracy: 0.9898 - val_loss: 0.0906 - val_accuracy: 0.9737
# Epoch 7/20
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.0292 - accuracy: 0.9903 - val_loss: 0.0935 - val_accuracy: 0.9743
# Epoch 8/20
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.0213 - accuracy: 0.9928 - val_loss: 0.0768 - val_accuracy: 0.9807
# Epoch 9/20
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.0212 - accuracy: 0.9929 - val_loss: 0.0937 - val_accuracy: 0.9771
# Epoch 10/20
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0173 - accuracy: 0.9943 - val_loss: 0.0901 - val_accuracy: 0.9792
# Epoch 11/20
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0181 - accuracy: 0.9946 - val_loss: 0.0961 - val_accuracy: 0.9776
# Epoch 12/20
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.0142 - accuracy: 0.9953 - val_loss: 0.1231 - val_accuracy: 0.9740
# Epoch 13/20
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0165 - accuracy: 0.9948 - val_loss: 0.1013 - val_accuracy: 0.9783
# Epoch 14/20
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.0100 - accuracy: 0.9967 - val_loss: 0.1069 - val_accuracy: 0.9792
# Epoch 15/20
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.0171 - accuracy: 0.9946 - val_loss: 0.1009 - val_accuracy: 0.9807
# Epoch 16/20
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0090 - accuracy: 0.9970 - val_loss: 0.1091 - val_accuracy: 0.9797
# Epoch 17/20
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0137 - accuracy: 0.9958 - val_loss: 0.1296 - val_accuracy: 0.9788
# Epoch 18/20
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.0096 - accuracy: 0.9969 - val_loss: 0.1203 - val_accuracy: 0.9805
# Epoch 19/20
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0110 - accuracy: 0.9966 - val_loss: 0.1199 - val_accuracy: 0.9785
# Epoch 20/20
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.0102 - accuracy: 0.9968 - val_loss: 0.1145 - val_accuracy: 0.9807

# %%
# Testing using TensorFlow/Keras
test_loss, test_accuracy = model.evaluate(x_test, y_test)
print("Test Accuracy:", test_accuracy)
# Out:
# 313/313 [==============================] - 0s 1ms/step - loss: 0.1145 - accuracy: 0.9807
# Test Accuracy: 0.9807000160217285

# %%
# Visualization using Matplotlib
import matplotlib.pyplot as plt

predictions = model.predict(x_test)
for i in range(5):  # Display predictions for the first 5 test images
    plt.imshow(x_test[i].reshape(28, 28), cmap='gray')
    plt.title(f"True: {y_test[i]}, Predicted: {tf.argmax(predictions[i])}")
    plt.show()
# Out:
# 313/313 [==============================] - 0s 1ms/step

# %%
model.save('model.h5')
# Out:
# C:\Users\Aamir\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\engine\training.py:3079: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %%
x_train[0].shape
# Out:
# (28, 28, 1)
